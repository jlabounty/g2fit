# %%
from si import *
# Out:
# Not a jupyter notebook. Not enabling notebook functions.
# Welcome to JupyROOT 6.22/00
# For interactive plots, run: setint()
# To return to non-interactive plots (default state), run: noint()

# %%
from g2Fitter import *
from root_to_boost import *
import uproot
# Out:
# /home/jlab/miniconda3/lib/ROOT/_facade.py:121: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   return _orig_ihook(name, *args, **kwds)
# /home/jlab/miniconda3/lib/python3.7/site-packages/luigi/scheduler.py:211: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class OrderedSet(collections.MutableSet):
# DEBUG: law - registered logger with level 'DEBUG'
# DEBUG: luigi-interface - registered logger with level 'DEBUG'
# DEBUG: law.target.formatter - registered target formatter 'text'
# DEBUG: law.target.formatter - registered target formatter 'json'
# DEBUG: law.target.formatter - registered target formatter 'pickle'
# DEBUG: law.target.formatter - registered target formatter 'yaml'
# DEBUG: law.target.formatter - registered target formatter 'zip'
# DEBUG: law.target.formatter - registered target formatter 'tar'
# /home/jlab/miniconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# 1

# %%
infile = "/home/jlab/g-2/omega_a_KS/data/results_clustersAndCoinc_unrandomized_July7_pileup_corrected.root"
f = r.TFile(infile)
h3 = f.Get("clustersAndCoincidences/corrected").Clone()
h3.GetYaxis().SetRangeUser(1700,3200)
h = h3.Project3D("x").Clone()
print(h)
# Out:
# Name: corrected_x Title: corrected x projection NbinsX: 4692

# %%
input_hist = rootToBoost.TH1ToBoost(None, h)

# %%
print((input_hist.axes[0].centers))
# Out:
# [7.45950554e-02 2.23785166e-01 3.72975277e-01 ... 6.99627025e+02
#  6.99776215e+02 6.99925405e+02]

# %%
fig,ax = plt.subplots(figsize=(15,5))
plt.plot(input_hist.axes[0].centers, input_hist.view().value)
plt.yscale("log")
plt.xlim(30,400)
plt.show()

# %% [markdown]
# ---
#
# ### Test of new iterative fit
